# %%
#(LETS GROW MORE) DATA SCIENCE INTERN

# %%
#Author = Akshanshu Bharti
$Task = 3
$level = Intermediate Level of Task

# %%
#Q.Prediction using Decision Tree  Algorithm :Create the Decision Tree classifier and visualize it graphically. 
The purpose is if we feed any new data to this classifier, it would be able to  predict the right class accordingly.

# %%
# Step 1 : Firstlly I imported all library ......

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sa

# %%
# Step 2 " Secondally i imported iris.csv file from my pc "

# %%
data = pd.read_csv("Iris.csv")
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
data.head(20)
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# ...

# %%
Step 3 : # I analysis the data of Iris.csv

# %%
data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
# Step 4 : I make a different graph with the help of matplotlib.

# %%
sa.pairplot(data=data,kind='scatter')
plt.show()

# %%
data.drop('Id',inplace=True,axis=1)
i
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
FEATURE_NAME = data[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]

# %%
FEATURE_NAME.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0            5.1           3.5            1.4           0.2
# 1            4.9           3.0            1.4           0.2
# 2            4.7           3.2            1.3           0.2
# 3            4.6           3.1            1.5           0.2
# 4            5.0           3.6            1.4           0.2

# %%
SPECIES_NAME = data[['Species']]
SPECIES_NAME
# Out:
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 1 columns]

# %%
SPECIES_NAME = data[['Species']]
SPECIES_NAME.head()
# Out:
#        Species
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %%
SPECIES_NAME.value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %%
SPECIES_NAME['Species'].replace(to_replace='Iris-setosa',value=0,inplace=True)
SPECIES_NAME['Species'].replace(to_replace='Iris-versicolor',value=1,inplace=True)
SPECIES_NAME['Species'].replace(to_replace='Iris-virginica',value=2,inplace=True)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\pandas\core\generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
from sklearn.model_selection import train_test_split
FEATURE_NAME_train,FEATURE_NAME_test,SPECIES_NAME_train,SPECIES_NAME_test = train_test_split(FEATURE_NAME,SPECIES_NAME,test_size=0.20,random_state=100)
print('Splitting is successful')
# Out:
# Splitting is successful

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

d_tree= DecisionTreeClassifier()
d_tree.fit( FEATURE_NAME_train,SPECIES_NAME_train )
print('Decision Tree Classifier is created successfully')
# Out:
# Decision Tree Classifier is created successfully

# %%
tree.plot_tree(d_tree)
# Out:
# [Text(133.92000000000002, 199.32, 'X[3] <= 0.8\ngini = 0.665\nsamples = 120\nvalue = [39, 44, 37]'),
#  Text(100.44000000000001, 163.07999999999998, 'gini = 0.0\nsamples = 39\nvalue = [39, 0, 0]'),
#  Text(167.40000000000003, 163.07999999999998, 'X[3] <= 1.65\ngini = 0.496\nsamples = 81\nvalue = [0, 44, 37]'),
#  Text(66.96000000000001, 126.83999999999999, 'X[2] <= 4.95\ngini = 0.156\nsamples = 47\nvalue = [0, 43, 4]'),
#  Text(33.480000000000004, 90.6, 'gini = 0.0\nsamples = 42\nvalue = [0, 42, 0]'),
#  Text(100.44000000000001, 90.6, 'X[0] <= 6.05\ngini = 0.32\nsamples = 5\nvalue = [0, 1, 4]'),
#  Text(66.96000000000001, 54.359999999999985, 'X[3] <= 1.55\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(33.480000000000004, 18.119999999999976, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(100.44000000000001, 18.119999999999976, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(133.92000000000002, 54.359999999999985, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
# ...

# %%
fn = ['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']
cn = ['Iris-setosa','Iris-versicolor','Iris-virginica']
fig,axes = plt.subplots(nrows = 1,ncols = 1,figsize = (4,4), dpi = 300)
tree.plot_tree(d_tree,feature_names = fn, class_names = cn,filled = True);
fig.savefig('Iris_Tree.png')

# %%
The conclussion is made that i sucessfully did decission tree classifier.

# %%
THank you
